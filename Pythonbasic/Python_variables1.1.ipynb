# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age=32
height=5.9
name="Shashank"
is_stdent=True

#printing the variable
print("age:",age)

print("height:",height)
print("name:",name)
# Out:
# age: 32
# height: 5.9
# name: Shashank

# %%
##nameing convention
#variable names should be descriptive
#they must start with a letter or "_", They can contain letters numbers and underscore
#variable names are case sensetives

#valid variable name
First_name="Shashank"
Last_name="Shivam"

# %%
#invalide variable names
'''//age =30
//first-name="shashan  '''
# Out:
# '//age =30\n//first-name="shashan  '

# %%
# Understanding variable types
# Python is dynammicaly typed, type of a variable is determined at runtime
age=25
height=6.1

# %%
print(type(height))
# Out:
# <class 'float'>

# %%
### Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 110.0
# Difference: -10.0
# Product: 3000.0
# Quotient: 0.8333333333333334
